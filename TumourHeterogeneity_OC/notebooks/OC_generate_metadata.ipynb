# %%
import os
import shutil
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Initialization

# %%
# Paths
root = '/cluster/dataset/tumorp/data_repository/metadata/gyn'
study = '/cluster/dataset/tumorp/data_repository/study'
path_scRNA_Analysis = '/datasets/scRNA_Analysis.csv'
path_Participants = '/datasets/Participants.csv'
path_OvarianCancer_sample = '/samplesets/OvarianCancer_Samples.csv'
excluded = ['OPELICI']

# %%
# Dataframes
scRNA_Analysis = pd.read_csv(root + path_scRNA_Analysis)
Participants = pd.read_csv(root + path_Participants)
OvarianCancer_sample = pd.read_csv(root + path_OvarianCancer_sample)

# %% [markdown]
# # Select candidates
# The candidates are the sample with the latest available 'Run' (pass) and sequencing version (note: the sequencing version should be 7.8 accross all sample to stay consistent, otherwise differences in technologies might introduce biases)

# %%
scRNA_Analysis_ = scRNA_Analysis[scRNA_Analysis['scOmicsSample'].str.startswith('O')]

# %%
run = scRNA_Analysis_.groupby(['scOmicsSample'])['Run'].max()
sop = scRNA_Analysis_.groupby(['scOmicsSample'])['SopVersion'].max()
tmp = np.array(scRNA_Analysis_)

# %%
arr = []
for i in range(len(tmp)):
    scomics=tmp[i][11]
    SopV=tmp[i][5]
    Run=tmp[i][7]
    if Run==run[scomics] and SopV==sop[scomics]:
        arr.append(tmp[i])
        
arr=np.array(arr)
preprocessing_candidates = pd.DataFrame(arr, columns=scRNA_Analysis_.columns).drop("Unnamed: 0",axis=1)

# %% [markdown]
# # Select existing sample
# All candidates do not find corresponding samples on the TuPro database, for unknown reasons that shall be investigated. We keep only the candidates for which a ".h5" file exists in the TuPro study

# %%
sample_paths = []
annotations_paths = []
OC_dataset = []

for i in range(len(arr)):
    participant_id = arr[i][9]
    name = arr[i][8]
    sample_id = arr[i][11].split("-")[0]
    n_pass = scRNA_Analysis[scRNA_Analysis['scOmicsSample']==arr[i][11]].shape[0]
    if excluded.count(sample_id) <= 0:
        curr_path = study + '/' + participant_id + '/' + sample_id + '/scRNA/derived/pass_' + str(n_pass)
        sPath = curr_path + '/' + name + '__raw.h5'
        aPath = curr_path + '/' + name + '__cts_final.txt'
        
        if os.path.exists(sPath) and os.path.exists(aPath):
            OC_dataset.append(np.ndarray.tolist(arr[i])+[sPath, aPath])

# %%
OC_dataset=pd.DataFrame(np.array(OC_dataset), columns=np.ndarray.tolist(np.array(scRNA_Analysis.columns)) + ['sample_path', 'annotation_path'])

# %% [markdown]
# # Gather information about dataset
# Finally a few measures are computed in order to characterize features for the Ovarian Cancer (OC) dataset that shall be preprocessed in later steps

# %%
oc = OvarianCancer_sample.groupby(by=['ParticipantID', 'Name', 'SampleType', 'Notes', 'LabOrigin', 'Location']).mean()

# %%
values_1=np.array([np.asarray(i) for i in oc.index])
values_2=np.array(oc.iloc[:,1:])

# %%
assert values_1.shape[0]==values_2.shape[0]

tmp = []
for i in range(values_1.shape[0]):
    tmp.append(list(values_1[i])+list(values_2[i]))

tmp = np.array(tmp)
tmp=pd.DataFrame(tmp, columns=['ParticipantId', 'Name', 'SampleType', 'Notes', 'LabOrigin', 'Location', 'RowId', 'TumorContent', 'VitalTumorCells'])

# %%
tmp_1 = np.array(tmp)
tmp_2 = np.array(OC_dataset)
tmp_3 = np.array(Participants)

# %%
OC_dataset_info=[]
for i in range(tmp_2.shape[0]):
    hit_1=False
    idx_1=-1
    hit_2=False
    idx_2=-1
    
    
    for j in range(tmp_1.shape[0]):
        if tmp_2[i][9]==tmp_1[j][0] and tmp_2[i][11].split('-')[0]==tmp_1[j][1]:
            hit_1=True
            idx_1=j
    for j in range(tmp_3.shape[0]):
        if tmp_2[i][9]==tmp_3[j][10]:
            hit_2=True
            idx_2=j
    
    if hit_1 and hit_2:
        OC_dataset_info.append(list(tmp_2[i])+list(tmp_1[idx_1])+list(tmp_3[idx_2]))
    elif hit_1:
        a=np.empty(tmp_3.shape[1])
        a[:]=np.NaN
        OC_dataset_info.append(list(tmp_2[i])+list(tmp_1[idx_1])+list(a))
    elif hit_2:
        a=np.empty(tmp_1.shape[1])
        a[:]=np.NaN
        OC_dataset_info.append(list(tmp_2[i])+list(a)+list(tmp_3[idx_2]))
    else:
        a=np.empty(tmp_1.shape[1])
        b=np.empty(tmp_3.shape[1])
        a[:]=np.NaN
        b[:]=np.NaN
        OC_dataset_info.append(list(tmp_2[i])+list(a)+list(b))
    
 


OC_dataset_info=np.array(OC_dataset_info)
OC_dataset_info=pd.DataFrame(OC_dataset_info, columns=list(OC_dataset)+list(tmp)+list(Participants))

# %%
relevant=[9,11,36,47,37,24,27,25,51,29,38,49,26,20]
OC_final=OC_dataset_info.iloc[:,relevant]

# %% [markdown]
# # Calculate some statistics about dataset
# We establish the nature of the samples, if we have relevant information about them

# %%
def get(column):
    labels=np.array(OC_final.groupby([column]).count().index)
    values=np.array(OC_final.groupby([column]).count().iloc[:,0])
    
    return [labels, values]

# %%
def plot_pie(title,labels, data):
    # Plot charts
    plt.figure(figsize=(4, 8), constrained_layout=True, dpi=300)
    plt.pie(data, autopct='%1.f%%')
    plt.legend(labels=labels)
    plt.title(title)

    plt.savefig('/cluster/home/antoinco/outputs/stats/'+title+'.png')

# %%
def print_stats(title, labels, data):
    print(title)
    print('-'*len(title)*2)
    dist=-1
    for i in labels:
        dist=max(dist, len(labels))
    for i in range(len(labels)):
        print(str(labels[i]) + ': ' + str(data[i]))
        
    print('')

# %%
information=[
    'SampleType',
    'Location',
    'Indication',
    'Stage',
    'SiteOfPrimaryTumor',
    'AgeRange']

# %%
for info in information:
    data=get(info)
    # print_stats(info, data[0], data[1])
    # plot_pie(info, data[0], data[1])

# %%
OC_final
# Out:
#      ParticipantId scOmicsSample      Indication              Stage  \
# 0    TP-G1-USB-010       OZ0G5-T   OvarianCancer               IIIC
# 1    TP-G1-USB-012   OY3WE-YRS-T   OvarianCancer                nan
# 2    TP-G2-USB-024     OXEXYCY-T   OvarianCancer                nan
# 3    TP-G2-USZ-002     OVIKYWA-T   OvarianCancer            FIGO IV
# 4    TP-G2-USZ-005     OVAMUZI-T   OvarianCancer                nan
# 5    TP-G1-USB-008       OTX01-T   OvarianCancer               IIIC
# 6    TP-G2-USB-012     OTEWUZO-T   OvarianCancer                nan
# 7    TP-G2-USB-015     OTAMAZA-T  Ovarian Cancer                nan
# 8    TP-G2-USB-030     ORESACE-T   OvarianCancer                nan
# 9    TP-G2-USB-036     ORAVAFU-T   OvarianCancer                nan
# 10   TP-G2-USB-035     ORAJIMY-T   OvarianCancer  at least FIGO III
# 11   TP-G2-USB-022     OQEMOGA-T   OvarianCancer                nan
# 12   TP-G2-USB-010     OQADOQU-T   OvarianCancer                nan
# 13   TP-G2-USB-050     OQADIRY-T   OvarianCancer                nan
# 14   TP-G2-USB-028     OPAPUHU-T   OvarianCancer                nan
# 15   TP-G1-USB-008   ONWLE-YR4-T   OvarianCancer               IIIC
# 16   TP-G2-USB-017     ONAKERE-T   OvarianCancer                 IV
# 17   TP-G2-USB-039     OMAJORO-T   OvarianCancer                nan
# 18   TP-G2-USB-053     OMAJIQI-T   OvarianCancer                nan
# 19   TP-G2-USB-032     OMABOPY-T     TubalCancer               IIIC
# 20   TP-G2-USB-037     OLEFUTI-T   OvarianCancer                 IV
# 21   TP-G1-USB-011   OKW5U-YRS-T   OvarianCancer               IIIC
# 22   TP-G2-USB-020     OKEKIDE-T   OvarianCancer                nan
# 23   TP-G2-USB-042     OKEBYDA-T   OvarianCancer                nan
# 24   TP-G2-USB-009     OKAGOCY-T   OvarianCancer                 IV
# 25   TP-G1-USB-009       OHU1D-T   OvarianCancer                nan
# 26   TP-G2-USB-023     OHANIQY-T   OvarianCancer                nan
# 27   TP-G2-USB-019     OHAMUME-T   OvarianCancer                nan
# 28   TP-G2-USB-018     OHACAHY-T   OvarianCancer                nan
# 29   TP-G2-USB-002     OGOBIGU-T   OvarianCancer                nan
# 30   TP-G2-USB-008     ODIDUKU-T   OvarianCancer                III
# 31   TP-G2-USB-031     ODEGOHY-T   OvarianCancer                nan
# 32   TP-G2-USB-034     ODAQUPA-T   OvarianCancer                nan
# 33   TP-G2-USB-021     ODAMILU-T   OvarianCancer                nan
# 34   TP-G1-USB-013     ODAJEGA-T   OvarianCancer                nan
# 35   TP-G2-USB-004     ODAFUGU-T   OvarianCancer                nan
# 36   TP-G2-USB-054     OCANYTE-T   OvarianCancer                nan
# 37   TP-G2-USB-044     OCAGEHY-T   OvarianCancer                nan
# 38  TP-G2-KSBL-001     OCABUGY-T   OvarianCancer                nan
# 39  TP-G1-KSBL-004     OBABEBU-T   OvarianCancer                nan
# 40   TP-G2-USB-006     OBABACY-T   OvarianCancer                nan
# 41   TP-G1-USB-007       OB225-T   OvarianCancer                nan
# 42   TP-G2-USB-056     OXUMUZU-T   OvarianCancer                nan
# 43   TP-G2-USB-057     OMEFOMO-T   OvarianCancer                nan
# 44   TP-G2-USB-055     OMAFYSU-T   OvarianCancer                nan
# 45  TP-G2-KSBL-007     OLEKESU-T   OvarianCancer                nan
# 46   TP-G2-USB-052     ONAHYPU-T   OvarianCancer                nan
# 47   TP-G2-USB-051     OQEFIRU-T   OvarianCancer                nan
#
#      SiteOfPrimaryTumor     SampleType    Location  \
# 0                 Ovary            nan         nan
# 1   ovary or peritoneum            nan         nan
# 2               unknown     metastasis     omentum
# 3                 ovary            nan         nan
# 4                 ovary            nan         nan
# 5                 Ovary            nan         nan
# 6                 ovary     metastasis  lymph node
# 7               unknown  primary tumor       ovary
# 8                 ovary  primary tumor       ovary
# 9                 ovary     metastasis     omentum
# 10           peritoneum     metastasis     omentum
# 11                  nan     metastasis  lymph node
# 12              unknown     metastasis     omentum
# 13                ovary     metastasis     unknown
# 14                  nan     metastasis     omentum
# 15                Ovary            nan         nan
# 16                ovary     metastasis     omentum
# 17                ovary            nan         nan
# 18                ovary     metastasis     omentum
# 19                 tube     metastasis     omentum
# 20                ovary     metastasis     unknown
# 21           Ovary/Tube            nan         nan
# 22                ovary     metastasis     omentum
# 23              unknown     metastasis     unknown
# 24                ovary     metastasis     omentum
# 25                Ovary            nan         nan
# 26                  nan     metastasis     omentum
# 27                ovary     metastasis     omentum
# 28                ovary            nan         nan
# 29                ovary            nan         nan
# 30                ovary     metastasis  peritoneum
# 31                ovary  primary tumor       ovary
# 32                ovary     metastasis     omentum
# 33                ovary     metastasis     unknown
# 34              OVARIAN            nan         nan
# 35                  nan            nan         nan
# 36              unknown     metastasis     unknown
# 37           peritoneum     metastasis     omentum
# 38                  nan            nan         nan
# 39                  nan            nan         nan
# 40                ovary  primary tumor     unknown
# 41                Ovary            nan         nan
# 42              unknown     metastasis     unknown
# 43                ovary     metastasis     omentum
# 44              unknown     metastasis     omentum
# 45                ovary            nan         nan
# 46                ovary     metastasis     omentum
# 47              unknown     metastasis     omentum
#
#                                                 Notes  \
# 0                                                 nan
# 1                                                 nan
# 2   1x 15ml tube with tumor in tissue storage solu...
# 3                                                 nan
# 4                                                 nan
# 5                                                 nan
# 6   1x 5ml tube with tissue (lymph node) in tissue...
# 7   1 x tissue in 5ml tube with tissue storage sol...
# 8             1x 15ml tube in tissue storage solution
# 9             1x 15ml tube in tissue storage solution
# 10                 1x 15ml in tissue storage solution
# 11  1x 15ml tube with tissue in tissue storage sol...
# 12                                            Omentum
# 13            1x 15ml tube in tissue storage solution
# 14            1x 15ml tube in tissue storage solution
# 15                                                nan
# 16  1x tissue in 15ml tube containing tissue stora...
# 17                                                nan
# 18          1x 15ml tube with tissue storage solution
# 19            1x 15ml tube in tissue storage solution
# 20                 1x 15ml in tissue storage solution
# 21                                                nan
# 22  1x 15ml tube with tissue in tissue storage sol...
# 23            1x 15ml tube in tissue storage solution
# 24  tissue in 1x 15ml tube containing tissue stora...
# 25                                                nan
# 26                                       omental cake
# 27            1x 15ml tube in tissue storage solution
# 28                                                nan
# 29                                                nan
# 30  1x15ml tube with tissue storage solution (tiss...
# 31            1x 15ml tube in tissue storage solution
# 32            1x 15ml tube in tissue storage solution
# 33                                            relapse
# 34                                                nan
# 35                                                nan
# 36          1x 15ml tube with tissue storage solution
# 37                 1x 15ml in tissue storage solution
# 38                                                nan
# 39                                                nan
# 40            1x 15ml tube in tissue storage solution
# 41                                                nan
# 42          1x 15ml tube with tissue storage solution
# 43          1x 15ml tube with tissue storage solution
# 44          1x 15ml tube with tissue storage solution
# 45                                                nan
# 46  1x 15ml tube with tissue in tissue storage sol...
# 47          1x 15ml tube with tissue storage solution
#
#                                                 Notes TumorContent AgeRange  \
# 0   SOC G3, FIGO IIIC, ER 40%, PR neg, neoadjuvant...          nan    70-79
# 1   high grade serous adenocarcinoma (determined f...          nan    70-79
# 2                                                 nan         90.0    60-69
# 3                                                 nan          nan    50-59
# 4                                                 nan          nan    50-59
# 5              CA125 64kU/l, HGSOC at least FIGO IIIC          nan    50-59
# 6                                                 nan         50.0    60-69
# 7                                                 nan         50.0    80-89
# 8                                                 nan         95.0    50-59
# 9                                                 nan         90.0    70-79
# 10                                                nan         40.0    70-79
# 11                                                nan         90.0    50-59
# 12                                                nan         10.0    70-79
# 13                                                nan         80.0    60-69
# 14  ovarian/tubal/peritoneal cancer at least FIGO ...         80.0    80-89
# 15             CA125 64kU/l, HGSOC at least FIGO IIIC          nan    50-59
# 16                             neo-adjuvant treatment         25.0    50-59
# 17                          high grade ovarian cancer          nan    70-79
# 18                                                nan         50.0    80-89
# 19                                   adjuvant setting          nan    80-89
# 20                                                nan         70.0    80-89
# 21  primary diagnosis, SOC G3 IIIC, CA125 356kU/l,...          nan    50-59
# 22                                                nan         70.0    50-59
# 23                                                nan          nan    90-99
# 24                                                nan         40.0    40-49
# 25  lymph node metastasis of a recurrent high-grad...          nan    80-89
# 26                                                nan         70.0    60-69
# 27                                                nan         70.0    70-79
# 28                                            relapse          nan    70-79
# 29                                                nan          nan    40-49
# 30                               patient with relapse         30.0    50-59
# 31                                                nan         90.0    60-69
# 32                                                nan         80.0    60-69
# 33                                            relapse         90.0    50-59
# 34                             07.06.19 CA125 150kU/l          nan    70-79
# 35                                                nan          nan    60-69
# 36                                                nan         80.0    60-69
# 37                                                nan          nan    70-79
# 38                             several pieces Omentum          nan      nan
# 39                                                nan          nan      nan
# 40                                            relapse         60.0    50-59
# 41  primary diagnosis (no neo-adjuvant setting), G...          nan    60-69
# 42                                                nan         90.0    70-79
# 43                                                nan         90.0    80-89
# 44                                                nan         90.0    70-79
# 45                                                nan          nan    70-79
# 46                                                nan          nan    60-69
# 47                                                nan         40.0    50-59
#
#                      Hospital            LabOrigin  \
# 0    Universitätsspital Basel                  nan
# 1    Universitätsspital Basel                  nan
# 2    Universitätsspital Basel  USB Heinzelmann Lab
# 3   Universitätsspital Zürich                  nan
# 4   Universitätsspital Zürich                  nan
# 5    Universitätsspital Basel                  nan
# 6    Universitätsspital Basel  USB Heinzelmann Lab
# 7    Universitätsspital Basel  USB Heinzelmann Lab
# 8    Universitätsspital Basel  USB Heinzelmann Lab
# 9    Universitätsspital Basel  USB Heinzelmann Lab
# 10   Universitätsspital Basel  USB Heinzelmann Lab
# 11   Universitätsspital Basel  USB Heinzelmann Lab
# 12   Universitätsspital Basel  USB Heinzelmann Lab
# 13   Universitätsspital Basel  USB Heinzelmann Lab
# 14   Universitätsspital Basel  USB Heinzelmann Lab
# 15   Universitätsspital Basel                  nan
# 16   Universitätsspital Basel  USB Heinzelmann Lab
# 17   Universitätsspital Basel                  nan
# 18   Universitätsspital Basel  USB Heinzelmann Lab
# 19   Universitätsspital Basel  USB Heinzelmann Lab
# 20   Universitätsspital Basel  USB Heinzelmann Lab
# 21   Universitätsspital Basel                  nan
# 22   Universitätsspital Basel  USB Heinzelmann Lab
# 23   Universitätsspital Basel  USB Heinzelmann Lab
# 24   Universitätsspital Basel  USB Heinzelmann Lab
# 25   Universitätsspital Basel                  nan
# 26   Universitätsspital Basel  USB Heinzelmann Lab
# 27   Universitätsspital Basel  USB Heinzelmann Lab
# 28   Universitätsspital Basel                  nan
# 29   Universitätsspital Basel                  nan
# 30   Universitätsspital Basel  USB Heinzelmann Lab
# 31   Universitätsspital Basel  USB Heinzelmann Lab
# 32   Universitätsspital Basel  USB Heinzelmann Lab
# 33   Universitätsspital Basel  USB Heinzelmann Lab
# 34   Universitätsspital Basel                  nan
# 35   Universitätsspital Basel                  nan
# 36   Universitätsspital Basel  USB Heinzelmann Lab
# 37   Universitätsspital Basel  USB Heinzelmann Lab
# 38    Kantonsspital Baselland                  nan
# 39    Kantonsspital Baselland                  nan
# 40   Universitätsspital Basel  USB Heinzelmann Lab
# 41   Universitätsspital Basel                  nan
# 42   Universitätsspital Basel  USB Heinzelmann Lab
# 43   Universitätsspital Basel  USB Heinzelmann Lab
# 44   Universitätsspital Basel  USB Heinzelmann Lab
# 45    Kantonsspital Baselland                  nan
# 46   Universitätsspital Basel  USB Heinzelmann Lab
# 47   Universitätsspital Basel  USB Heinzelmann Lab
#
#                                           sample_path
# 0   /cluster/dataset/tumorp/data_repository/study/...
# 1   /cluster/dataset/tumorp/data_repository/study/...
# 2   /cluster/dataset/tumorp/data_repository/study/...
# 3   /cluster/dataset/tumorp/data_repository/study/...
# 4   /cluster/dataset/tumorp/data_repository/study/...
# 5   /cluster/dataset/tumorp/data_repository/study/...
# 6   /cluster/dataset/tumorp/data_repository/study/...
# 7   /cluster/dataset/tumorp/data_repository/study/...
# 8   /cluster/dataset/tumorp/data_repository/study/...
# 9   /cluster/dataset/tumorp/data_repository/study/...
# 10  /cluster/dataset/tumorp/data_repository/study/...
# 11  /cluster/dataset/tumorp/data_repository/study/...
# 12  /cluster/dataset/tumorp/data_repository/study/...
# 13  /cluster/dataset/tumorp/data_repository/study/...
# 14  /cluster/dataset/tumorp/data_repository/study/...
# 15  /cluster/dataset/tumorp/data_repository/study/...
# 16  /cluster/dataset/tumorp/data_repository/study/...
# 17  /cluster/dataset/tumorp/data_repository/study/...
# 18  /cluster/dataset/tumorp/data_repository/study/...
# 19  /cluster/dataset/tumorp/data_repository/study/...
# 20  /cluster/dataset/tumorp/data_repository/study/...
# 21  /cluster/dataset/tumorp/data_repository/study/...
# 22  /cluster/dataset/tumorp/data_repository/study/...
# 23  /cluster/dataset/tumorp/data_repository/study/...
# 24  /cluster/dataset/tumorp/data_repository/study/...
# 25  /cluster/dataset/tumorp/data_repository/study/...
# 26  /cluster/dataset/tumorp/data_repository/study/...
# 27  /cluster/dataset/tumorp/data_repository/study/...
# 28  /cluster/dataset/tumorp/data_repository/study/...
# 29  /cluster/dataset/tumorp/data_repository/study/...
# 30  /cluster/dataset/tumorp/data_repository/study/...
# 31  /cluster/dataset/tumorp/data_repository/study/...
# 32  /cluster/dataset/tumorp/data_repository/study/...
# 33  /cluster/dataset/tumorp/data_repository/study/...
# 34  /cluster/dataset/tumorp/data_repository/study/...
# 35  /cluster/dataset/tumorp/data_repository/study/...
# 36  /cluster/dataset/tumorp/data_repository/study/...
# 37  /cluster/dataset/tumorp/data_repository/study/...
# 38  /cluster/dataset/tumorp/data_repository/study/...
# 39  /cluster/dataset/tumorp/data_repository/study/...
# 40  /cluster/dataset/tumorp/data_repository/study/...
# 41  /cluster/dataset/tumorp/data_repository/study/...
# 42  /cluster/dataset/tumorp/data_repository/study/...
# 43  /cluster/dataset/tumorp/data_repository/study/...
# 44  /cluster/dataset/tumorp/data_repository/study/...
# 45  /cluster/dataset/tumorp/data_repository/study/...
# 46  /cluster/dataset/tumorp/data_repository/study/...
# 47  /cluster/dataset/tumorp/data_repository/study/...
